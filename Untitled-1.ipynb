# %%
import pandas as pd
Content = pd.read_csv('Content.csv')
Content
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID Content Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43        photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4        photo   healthy eating
# ...

# %%
import pandas as pd
Reactions = pd.read_csv('Reactions.csv')
Reactions
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# ...

# %%
import pandas as pd
ReactionTypes = pd.read_csv('ReactionTypes.csv')
ReactionTypes
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
Content=Content.dropna()
Content
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 994         994  c54b49c4-b1f2-4641-8595-1cbd19937845
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID Content Type        Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo        Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43        photo  healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4        photo  healthy eating
# ...

# %%
Reactions=Reactions.dropna()
Reactions
# Out:
#        Unnamed: 0                            Content ID  \
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# ...

# %%
ReactionTypes=ReactionTypes.dropna()
ReactionTypes
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
Content.drop(columns=['URL'], inplace=True)
Content
# Out:
# C:\Users\HILARY\AppData\Local\Temp\ipykernel_15072\3268047147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Content.drop(columns=['URL'], inplace=True)
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 994         994  c54b49c4-b1f2-4641-8595-1cbd19937845
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# ...

# %%
ReactionTypes.rename(columns={'Type':'Content Type'})
# Out:
#     Unnamed: 0 Content Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
Reactions.drop(columns=['User ID'], inplace=True)
Reactions
# Out:
# C:\Users\HILARY\AppData\Local\Temp\ipykernel_15072\1200217920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Reactions.drop(columns=['User ID'], inplace=True)
#        Unnamed: 0                            Content ID        Type  \
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
# ...           ...                                   ...         ...
# 25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike
# ...

# %%
Content.drop(columns=['User ID'], inplace=True)
Content
# Out:
# C:\Users\HILARY\AppData\Local\Temp\ipykernel_15072\2780558138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Content.drop(columns=['User ID'], inplace=True)
#      Unnamed: 0                            Content ID Content Type  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6        photo
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180        video
# ..          ...                                   ...          ...
# 994         994  c54b49c4-b1f2-4641-8595-1cbd19937845        photo
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c          GIF
# ...

# %%
Reactions
# Out:
#        Unnamed: 0                            Content ID        Type  \
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
# ...           ...                                   ...         ...
# 25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish
#
#                   Datetime
# 1      2020-11-07 09:43:50
# 2      2021-06-17 12:22:51
# 3      2021-04-18 05:13:58
# 4      2021-01-06 19:13:01
# ...

# %%
ReactionTypes
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
Reactions
# Out:
#        Unnamed: 0                            Content ID        Type  \
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
# ...           ...                                   ...         ...
# 25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish
#
#                   Datetime
# 1      2020-11-07 09:43:50
# 2      2021-06-17 12:22:51
# 3      2021-04-18 05:13:58
# 4      2021-01-06 19:13:01
# ...

# %%
New= Reactions.merge(Content, on='Content ID')
New
# Out:
#        Unnamed: 0_x                            Content ID        Type  \
# 0                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 1                 2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 2                 3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 3                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 4                 5  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
# ...             ...                                   ...         ...
# 18379         25547  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 18380         25548  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike
# 18381         25549  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued
# 18382         25551  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 18383         25552  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish
#
#                   Datetime  Unnamed: 0_y Content Type    Category
# ...

# %%
New2 = New.merge(ReactionTypes, on='Type')
New2
# Out:
#        Unnamed: 0_x                            Content ID        Type  \
# 0                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 1                 2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 2                 3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 3                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 4                 5  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
# ...             ...                                   ...         ...
# 18379         25547  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 18380         25548  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike
# 18381         25549  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued
# 18382         25551  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 18383         25552  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish
#
#                   Datetime  Unnamed: 0_y Content Type    Category  Unnamed: 0  \
# ...

# %%
New2.groupby('Category').sum()
# Out:
#                  Unnamed: 0_x  \
# Category
# Studying                  935
# animals              19946170
# cooking              16970296
# culture              16982958
# dogs                 12745798
# education            12962476
# fitness              14718383
# food                 14782111
# healthy eating       16189332
# public speaking      10388473
# science              18592558
# soccer               12957763
# studying              9813685
# technology           13918982
# tennis               13676263
# travel               17672395
# veganism             11975541
#
#                                                         Content ID  \
# Category
# Studying         97522e57-d9ab-4bd6-97bf-c24d952602d297522e57-d...
# animals          4fa14453-7b29-4302-b51f-9aa23b472c1b4fa14453-7...
# cooking          02fa1c4f-722d-46d2-a85e-e5b136b5f3bc02fa1c4f-7...
# culture          259cd56f-b017-4a41-81a7-f26ce9b35092259cd56f-b...
# ...

# %%
New3=New2.sort_values('Score', ascending=False).head(5)
New3.to_csv('NewFile.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[25], line 2
#       1 New3=New2.sort_values('Score', ascending=False).head(5)
# ----> 2 New3.to_csv('NewFile.csv', index=False)
#
# File c:\Users\HILARY\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.figure(figsize=(8,8))

# %%
import pandas as pd
new3 = pd.read_csv('NewFile.csv')
# Set the 'Category' as the index and plot the pie chart using 'Values'
new3.set_index('Score', inplace=True)

# Plotting the pie chart
New3['Score'].plot.pie(autopct='%1.1f%%', figsize=(6, 6), startangle=90, colormap='Pastel1')

# Add title
plt.title('Pie Chart of Categories')

# Show the plot
plt.ylabel('y')  # Optional: Hide the y-label
plt.show()
